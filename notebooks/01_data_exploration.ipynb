# %%
# %% [markdown]
# # 01. Exploratory Data Analysis: Yerevan Air Quality
#
# ## Objective
# Understand PM2.5 patterns, data quality, and initial trends in Yerevan.

# %% [code]
# Import libraries
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Add project root to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Import custom modules
from src.data.data_loader import AirQualityDataLoader
from src.data.data_cleaning import AirQualityCleaner

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
sns.set_context("notebook", font_scale=1.2)
# %matplotlib inline

print("Setup complete!")
